# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Original Model

# %%
N = 30
C = np.linspace(-3, 3, N) ** 3

# %%
x01 = np.linspace(0, 10, N) + C
x02 = x01 + 2 * x01 + C
y0 = x01**2 + x02

# %%
plt.plot(x01, y0, 'k.')
plt.xlabel("x1")
plt.ylabel("y")
plt.show()

# %%
plt.plot(x02, y0, 'k.')
plt.xlabel("x2")
plt.ylabel("y")
plt.show()

# %%
plt.plot(x01, x02, 'k.')
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %% [markdown]
# So, there is likely a path x1 -- x2 or a counfounder of the two.

# %% [markdown]
# # do(x2 = a)

# %%
a = 35

# %%
x11 = x01
x12 = [a] * N
y1 = x11**2 + x12

# %%
plt.plot(x01, y1, 'r.', label = 'do(x2 = a)')

plt.legend()
plt.xlabel("x1")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Since x1 ~ y, the path direction is likely x1 --> x2, not confirmed yet.

# %% [markdown]
# # do(x1 = a)

# %%
a = 10
x21 = a * np.ones(N)
x22 = x21 + 2 * x21 + C
y2 = x21**2 + x22

# %%
plt.plot(x02, y2, 'g.', label = 'do(x1 = a)')

plt.legend()
plt.xlabel("x2")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Since y ~ x2, there is a counfounder for x1 and x2 and we don't know if there is a path x1 -- x2.
